# %%
from rules.pitch_names import *
from rules.chord2symbol import *
from rules.chord_symbols import *
from rules.intervals import *

import mingus.core.chords
import music21.chord, music21.harmony
import musthe
import pychord

# %%
'''
! pip install mingus
! pip install music21
! pip install musthe
! pip install pychord
'''

# %% [markdown]
# # pitch name to pitch num

# %%
list_pitch_name_to_num(["C","G","E"], default_bias = 48, ordered = True)
# Out:
# [48, 55, 64]

# %%
list_pitch_name_to_num(["C","G","E"], default_bias = 48, ordered = False)
# Out:
# [48, 52, 55]

# %%
list_pitch_name_to_num(["C3","G3","E4"], ordered = False)
# Out:
# [48, 55, 64]

# %% [markdown]
# # get chroma24 and chord inversions

# %% [markdown]
# ## C Major chord in open position

# %%
chord_notes = list_pitch_name_to_num(["C","G","E"], default_bias = 48, ordered = True)
bass, chroma24 = get_bass_chroma24(chord_notes)
print(bass, chroma24)
# Out:
# 48 [4, 7]

# %%
for i in range(3):
    bass, chroma24 = invert(bass, chroma24)
    print(bass, chroma24)
# Out:
# 52 [3, 8]
# 55 [5, 9]
# 60 [4, 7]

# %%
for i in range(3):
    bass, chroma24 = inv_invert(bass, chroma24)
    print(bass, chroma24)
# Out:
# 55 [5, 9]
# 52 [3, 8]
# 48 [4, 7]

# %% [markdown]
# ## C69 chord

# %%
chord_notes = list_pitch_name_to_num(["C","E","A","D","G"], default_bias = 48, ordered = True)
bass, chroma24 = get_bass_chroma24(chord_notes)
print(bass, chroma24)
# Out:
# 48 [4, 7, 9, 14]

# %%
for i in range(5):
    bass, chroma24 = invert(bass, chroma24)
    print(bass, chroma24)
# Out:
# 52 [3, 5, 10, 20]
# 55 [2, 7, 17, 21]
# 57 [5, 15, 19, 22]
# 62 [10, 14, 17, 19]
# 60 [4, 7, 9, 14]

# %%
for i in range(5):
    bass, chroma24 = inv_invert(bass, chroma24)
    print(bass, chroma24)
# Out:
# 62 [10, 14, 17, 19]
# 57 [5, 15, 19, 22]
# 55 [2, 7, 17, 21]
# 52 [3, 5, 10, 20]
# 48 [4, 7, 9, 14]

# %% [markdown]
# ## C7, 2nd inversion

# %%
chord_notes = list_pitch_name_to_num(["G","Bb","C","E","G","E"], default_bias = 48, ordered = True)
bass, chroma24 = get_bass_chroma24(chord_notes)
print(bass, chroma24)
# Out:
# 55 [3, 5, 9]

# %%
for i in range(6):
    bass, chroma24 = invert(bass, chroma24)
    print(bass, rectify_chroma24(chroma24))
# Out:
# 58 [2, 6, 9]
# 60 [4, 7, 10]
# 64 [3, 6, 8]
# 67 [3, 5, 9]
# 70 [2, 6, 9]
# 72 [4, 7, 10]

# %%
for i in range(6):
    bass, chroma24 = inv_invert(bass, chroma24)
    print(bass, rectify_chroma24(chroma24))
# Out:
# 70 [2, 6, 9]
# 67 [3, 5, 9]
# 64 [3, 6, 8]
# 60 [4, 7, 10]
# 58 [2, 6, 9]
# 55 [3, 5, 9]

# %% [markdown]
# ## Cdim7

# %%
chord_notes = list_pitch_name_to_num(["C","Eb","Gb","A","C","Eb"], default_bias = 48, ordered = True)
bass, chroma24 = get_bass_chroma24(chord_notes)
print(bass, chroma24)
# Out:
# 48 [3, 6, 9]

# %%
for i in range(6):
    bass, chroma24 = invert(bass, chroma24)
    print(bass, rectify_chroma24(chroma24))
# Out:
# 51 [3, 6, 9]
# 54 [3, 6, 9]
# 57 [3, 6, 9]
# 60 [3, 6, 9]
# 63 [3, 6, 9]
# 66 [3, 6, 9]

# %%
for i in range(6):
    bass, chroma24 = inv_invert(bass, chroma24)
    print(bass, rectify_chroma24(chroma24))
# Out:
# 63 [3, 6, 9]
# 60 [3, 6, 9]
# 57 [3, 6, 9]
# 54 [3, 6, 9]
# 51 [3, 6, 9]
# 48 [3, 6, 9]

# %% [markdown]
# # Chord2symbol comprehensive test

# %%
def test_chords(chords_to_test, detect_inversion = True, list_all = True):
    for chord in chords_to_test:
        chord_notes = list_pitch_name_to_num(chord, default_bias = 48, ordered = True)
        bass, chroma24 = get_bass_chroma24(chord_notes)
        print(chord, bass, chroma24)
        symb = bass_chroma24_to_chord_name(
            bass, chroma24, 
            detect_inversion = detect_inversion, list_all = list_all
        )
        print("our result: ", symb)
        try:
            print("mingus result: ", mingus.core.chords.determine(chord))
        except Exception as e:
            print(e)
        music21_chord = music21.chord.Chord(chord_notes)
        music21_chord_symb = music21.harmony.chordSymbolFigureFromChord(music21_chord, includeChordType=True)
        print("music21 commonName result: ", music21_chord.commonName)
        print("music21 chordSymb  result: ", music21_chord_symb)
        print("pychord result: ", pychord.find_chords_from_notes(chord))

        print("---")

# %%
chords_to_test = [
    ["C","E","G"],
    ["C","Eb","G"],
    ["C","E","G#"],
    ["C","Eb","G#"],
    ["C","E","Gb"],
    ["C","Eb","Gb"],
    
    ["C","E","G","B"],
    ["C","Eb","G","B"],
    ["C","E","G#","B"],
    ["C","Eb","G#","B"],
    ["C","E","Gb","B"],
    ["C","Eb","Gb","B"],
    ["C","E","G","Bb"],
    ["C","Eb","G","Bb"],
    ["C","E","G#","Bb"],
    ["C","Eb","G#","Bb"],
    ["C","E","Gb","Bb"],
    ["C","Eb","Gb","Bb"],
    ["C","E","G","A"],
    ["C","Eb","G","A"],
    ["C","E","G#","A"],
    ["C","Eb","G#","A"],
    ["C","E","Gb","A"],
    ["C","Eb","Gb","A"],
    
    ["C","E","G","B","D"],
    ["C","Eb","G","B","D"],
    ["C","E","G#","B","D"],
    ["C","Eb","G#","B","D"],
    ["C","E","Gb","B","D"],
    ["C","Eb","Gb","B","D"],
    ["C","E","G","Bb","D"],
    ["C","Eb","G","Bb","D"],
    ["C","E","G#","Bb","D"],
    ["C","Eb","G#","Bb","D"],
    ["C","E","Gb","Bb","D"],
    ["C","Eb","Gb","Bb","D"],
    ["C","E","G","A","D"],
    ["C","Eb","G","A","D"],
    ["C","E","G#","A","D"],
    ["C","Eb","G#","A","D"],
    ["C","E","Gb","A","D"],
    ["C","Eb","Gb","A","D"],
]
test_chords(chords_to_test)
# Out:
# ['C', 'E', 'G'] 48 [4, 7]
# our result:  ['C-major']
# mingus result:  ['C major triad']
# music21 commonName result:  major triad
# music21 chordSymb  result:  ('C', 'major')
# pychord result:  [<Chord: C>]
# ---
# ['C', 'Eb', 'G'] 48 [3, 7]
# our result:  ['C-minor', 'Eb-major-sixth-on-C']
# mingus result:  ['C minor triad', 'Eb major sixth, second inversion']
# music21 commonName result:  minor triad
# music21 chordSymb  result:  ('Cm', 'minor')
# pychord result:  [<Chord: Cm>]
# ---
# ['C', 'E', 'G#'] 48 [4, 8]
# our result:  ['C-augmented', 'Ab-augmented-on-C', 'E-augmented-on-C']
# mingus result:  ['C augmented triad']
# music21 commonName result:  augmented triad
# music21 chordSymb  result:  ('C+', 'augmented')
# pychord result:  [<Chord: Caug>, <Chord: Eaug/C>, <Chord: G#aug/C>]
# ---
# ['C', 'Eb', 'G#'] 48 [3, 8]
# our result:  ['Ab-major-on-C']
# mingus result:  []
# music21 commonName result:  major triad
# music21 chordSymb  result:  ('A-/C', 'major')
# pychord result:  [<Chord: G#/C>]
# ---
# ['C', 'E', 'Gb'] 48 [4, 6]
# our result:  ['C-major-b5', 'Gb-half-diminished-seventh-on-C']
# mingus result:  ['C dominant flat five']
# music21 commonName result:  incomplete half-diminished seventh chord
# music21 chordSymb  result:  ('Chord Symbol Cannot Be Identified', '')
# pychord result:  [<Chord: C(b5)>]
# ---
# ['C', 'Eb', 'Gb'] 48 [3, 6]
# our result:  ['C-diminished', 'Eb-minor-sixth-on-C']
# mingus result:  ['C diminished triad', 'Eb minor sixth, second inversion']
# music21 commonName result:  diminished triad
# music21 chordSymb  result:  ('Cdim', 'diminished')
# pychord result:  [<Chord: Cdim>]
# ---
# ['C', 'E', 'G', 'B'] 48 [4, 7, 11]
# our result:  ['C-major-seventh', 'E-minor-on-C']
# mingus result:  ['C major seventh', 'Em|CM']
# music21 commonName result:  major seventh chord
# music21 chordSymb  result:  ('Cmaj7', 'major-seventh')
# pychord result:  [<Chord: CM7>]
# ---
# ['C', 'Eb', 'G', 'B'] 48 [3, 7, 11]
# our result:  ['C-minor-major-seventh']
# mingus result:  ['C minor/major seventh', 'Ebaug|Cm']
# music21 commonName result:  minor-augmented tetrachord
# music21 chordSymb  result:  ('CmM7', 'minor-major-seventh')
# pychord result:  [<Chord: CmM7>]
# ---
# ['C', 'E', 'G#', 'B'] 48 [4, 8, 11]
# our result:  ['C-augmented-major-seventh', 'E-major-on-C']
# mingus result:  ['C augmented major seventh', 'EM|Caug']
# music21 commonName result:  augmented major tetrachord
# music21 chordSymb  result:  ('C+M7', 'augmented-major-seventh')
# pychord result:  [<Chord: CM7+5>]
# ---
# ['C', 'Eb', 'G#', 'B'] 48 [3, 8, 11]
# our result:  ['C-minor-major-seventh-#5', 'C-augmented-major-seventh-#9']
# mingus result:  []
# music21 commonName result:  major-minor tetramirror
# music21 chordSymb  result:  ('A-/CaddC-', 'major')
# pychord result:  []
# ---
# ['C', 'E', 'Gb', 'B'] 48 [4, 6, 11]
# our result:  ['C-major-seventh-b5', 'Gb-half-diminished-11th-on-C']
# mingus result:  []
# music21 commonName result:  minor-second quartal tetrachord
# music21 chordSymb  result:  ('Chord Symbol Cannot Be Identified', '')
# pychord result:  []
# ---
# ['C', 'Eb', 'Gb', 'B'] 48 [3, 6, 11]
# our result:  ['C-diminished-major-seventh', 'C-minor-major-seventh-b5']
# mingus result:  []
# music21 commonName result:  major-diminished tetrachord
# music21 chordSymb  result:  ('CdimaddC-', 'diminished')
# pychord result:  []
# ---
# ['C', 'E', 'G', 'Bb'] 48 [4, 7, 10]
# our result:  ['C-dominant-seventh', 'E-diminished-on-C', 'G-minor-sixth-11th-on-C']
# mingus result:  ['C dominant seventh', 'Edim|CM']
# music21 commonName result:  dominant seventh chord
# music21 chordSymb  result:  ('C7', 'dominant-seventh')
# pychord result:  [<Chord: C7>, <Chord: Edim6/C>]
# ---
# ['C', 'Eb', 'G', 'Bb'] 48 [3, 7, 10]
# our result:  ['C-minor-seventh', 'Eb-major-on-C', 'Eb-major-sixth-on-C']
# mingus result:  ['C minor seventh', 'Eb major sixth, third inversion', 'EbM|Cm']
# music21 commonName result:  minor seventh chord
# music21 chordSymb  result:  ('Cm7', 'minor-seventh')
# pychord result:  [<Chord: Cm7>, <Chord: Eb6/C>]
# ---
# ['C', 'E', 'G#', 'Bb'] 48 [4, 8, 10]
# our result:  ['C-dominant-seventh-#5', 'Bb-half-diminished-ninth-on-C']
# mingus result:  ['C augmented minor seventh', 'E7b5|Caug']
# music21 commonName result:  augmented seventh chord
# music21 chordSymb  result:  ('F-+/CaddB-', 'augmented')
# pychord result:  [<Chord: C7+5>]
# ---
# ['C', 'Eb', 'G#', 'Bb'] 48 [3, 8, 10]
# our result:  ['C-alt', 'C-minor-seventh-#5', 'Bb-suspended-seventh-on-C', 'Ab-major-2-on-C']
# mingus result:  []
# music21 commonName result:  major-second major tetrachord
# music21 chordSymb  result:  ('A-/CaddB-', 'major')
# pychord result:  [<Chord: Cm7+5>]
# ---
# ['C', 'E', 'Gb', 'Bb'] 48 [4, 6, 10]
# our result:  ['C-dominant-seventh-b5', 'Gb-dominant-seventh-b5-on-C']
# mingus result:  ['C dominant flat five']
# music21 commonName result:  French augmented sixth chord
# music21 chordSymb  result:  ('F#dom7dim5/C', 'seventh-flat-five')
# pychord result:  [<Chord: C7-5>, <Chord: Gb7-5/C>]
# ---
# ['C', 'Eb', 'Gb', 'Bb'] 48 [3, 6, 10]
# our result:  ['C-half-diminished-seventh', 'Eb-minor-on-C', 'Eb-minor-sixth-on-C']
# mingus result:  ['C half diminished seventh', 'Eb minor sixth, third inversion', 'Ebm|Cdim']
# music21 commonName result:  half-diminished seventh chord
# music21 chordSymb  result:  ('Cø7', 'half-diminished-seventh')
# pychord result:  [<Chord: Cm7-5>, <Chord: Ebm6/C>]
# ---
# ['C', 'E', 'G', 'A'] 48 [4, 7, 9]
# our result:  ['C-major-sixth', 'A-minor-seventh-on-C']
# mingus result:  ['C major sixth', 'A minor seventh, first inversion']
# music21 commonName result:  minor seventh chord
# music21 chordSymb  result:  ('Am7/C', 'minor-seventh')
# pychord result:  [<Chord: C6>, <Chord: Am7/C>]
# ---
# ['C', 'Eb', 'G', 'A'] 48 [3, 7, 9]
# our result:  ['C-minor-sixth', 'A-half-diminished-seventh-on-C']
# mingus result:  ['C minor sixth', 'A half diminished seventh, first inversion']
# music21 commonName result:  half-diminished seventh chord
# music21 chordSymb  result:  ('Aø7/C', 'half-diminished-seventh')
# pychord result:  [<Chord: Cm6>, <Chord: Am7-5/C>]
# ---
# ['C', 'E', 'G#', 'A'] 48 [4, 8, 9]
# our result:  ['C-augmented-13', 'A-minor-major-seventh-on-C']
# mingus result:  ['A minor/major seventh, first inversion']
# music21 commonName result:  minor-augmented tetrachord
# music21 chordSymb  result:  ('AmM7/C', 'minor-major-seventh')
# pychord result:  [<Chord: AmM7/C>]
# ---
# ['C', 'Eb', 'G#', 'A'] 48 [3, 8, 9]
# our result:  ['C-minor-sixth-#5', 'A-diminished-major-seventh-on-C']
# mingus result:  []
# music21 commonName result:  major-diminished tetrachord
# music21 chordSymb  result:  ('A-/CaddA', 'major')
# pychord result:  []
# ---
# ['C', 'E', 'Gb', 'A'] 48 [4, 6, 9]
# our result:  ['C-major-sixth-b5', 'A-minor-sixth-on-C', 'Gb-half-diminished-seventh-on-C']
# mingus result:  []
# music21 commonName result:  half-diminished seventh chord
# music21 chordSymb  result:  ('F#ø7/C', 'half-diminished-seventh')
# pychord result:  [<Chord: Gbm7-5/C>, <Chord: Am6/C>]
# ---
# ['C', 'Eb', 'Gb', 'A'] 48 [3, 6, 9]
# our result:  ['C-diminished-seventh', 'Eb-diminished-on-C', 'A-diminished-seventh-on-C', 'Gb-diminished-seventh-on-C', 'Eb-diminished-seventh-on-C']
# mingus result:  ['A diminished seventh, first inversion']
# music21 commonName result:  diminished seventh chord
# music21 chordSymb  result:  ('F#o7/C', 'diminished-seventh')
# pychord result:  [<Chord: Cdim7>, <Chord: Ebdim7/C>, <Chord: Gbdim7/C>, <Chord: Adim7/C>]
# ---
# ['C', 'E', 'G', 'B', 'D'] 48 [4, 7, 11, 14]
# our result:  ['C-major-ninth', 'E-minor-seventh-on-C', 'D-suspended-13th-on-C']
# mingus result:  ['C major ninth', 'GM|CM', 'GM|CM7', 'Em7|CM', 'Em7|CM7']
# music21 commonName result:  major-ninth chord
# music21 chordSymb  result:  ('CM9', 'major-ninth')
# pychord result:  [<Chord: CM9>]
# ---
# ['C', 'Eb', 'G', 'B', 'D'] 48 [3, 7, 11, 14]
# our result:  ['C-minor-ninth-major-seventh', 'Eb-augmented-major-13th-on-C']
# mingus result:  ['GM|Cm', 'GM|Cm/M7', 'EbM7+|Cm', 'EbM7+|Cm/M7']
# music21 commonName result:  minor-major ninth chord
# music21 chordSymb  result:  ('CmM9', 'minor-major-ninth')
# pychord result:  []
# ---
# ['C', 'E', 'G#', 'B', 'D'] 48 [4, 8, 11, 14]
# our result:  ['C-augmented-major-ninth', 'E-dominant-seventh-on-C']
# mingus result:  ['G#dim|Caug', 'G#dim|CM7+', 'E7|Caug', 'E7|CM7+']
# music21 commonName result:  augmented-diminished ninth chord
# music21 chordSymb  result:  ('C+M9', 'augmented-major-ninth')
# pychord result:  [<Chord: E7-13/C>]
# ---
# ['C', 'Eb', 'G#', 'B', 'D'] 48 [3, 8, 11, 14]
# our result:  ['C-minor-ninth-major-seventh-#5', 'C-augmented-major-ninth-#9', 'Eb-augmented-major-13th-on-C']
# mingus result:  []
# music21 commonName result:  major-minor diminished pentachord
# music21 chordSymb  result:  ('A-/CaddD,C-', 'major')
# pychord result:  []
# ---
# ['C', 'E', 'Gb', 'B', 'D'] 48 [4, 6, 11, 14]
# our result:  ['C-major-ninth-b5', 'D-dominant-13th-on-C', 'Gb-half-diminished-b13-on-C']
# mingus result:  []
# music21 commonName result:  phrygian pentachord
# music21 chordSymb  result:  ('Bm/CaddE', 'minor')
# pychord result:  []
# ---
# ['C', 'Eb', 'Gb', 'B', 'D'] 48 [3, 6, 11, 14]
# our result:  ['C-minor-ninth-major-seventh-b5', 'C-diminished-major-ninth', 'D-dominant-13th-b9-on-C']
# mingus result:  []
# music21 commonName result:  major-minor-diminished pentachord
# music21 chordSymb  result:  ('CdimaddD,C-', 'diminished')
# pychord result:  []
# ---
# ['C', 'E', 'G', 'Bb', 'D'] 48 [4, 7, 10, 14]
# our result:  ['C-dominant-ninth', 'E-half-diminished-seventh-on-C', 'E-half-diminished-b13-on-C']
# mingus result:  ['C dominant ninth', 'Gm|CM', 'Gm|C7', 'Em7b5|CM', 'Em7b5|C7']
# music21 commonName result:  dominant-ninth
# music21 chordSymb  result:  ('C9', 'dominant-ninth')
# pychord result:  [<Chord: C9>]
# ---
# ['C', 'Eb', 'G', 'Bb', 'D'] 48 [3, 7, 10, 14]
# our result:  ['C-minor-ninth', 'Eb-major-seventh-on-C', 'Eb-major-13th-on-C']
# mingus result:  ['C minor ninth', 'Gm|Cm', 'Gm|Cm7', 'EbM7|Cm', 'EbM7|Cm7']
# music21 commonName result:  minor-ninth chord
# music21 chordSymb  result:  ('Cm9', 'minor-ninth')
# pychord result:  [<Chord: Cm9>]
# ---
# ['C', 'E', 'G#', 'Bb', 'D'] 48 [4, 8, 10, 14]
# our result:  ['C-dominant-ninth-#5', 'D-half-diminished-b13-on-C', 'Bb-dominant-seventh-#11-on-C']
# mingus result:  ['E7b5|Caug', 'E7b5|Cm7+']
# music21 commonName result:  whole-tone pentachord
# music21 chordSymb  result:  ('Chord Symbol Cannot Be Identified', '')
# pychord result:  [<Chord: C9+5>]
# ---
# ['C', 'Eb', 'G#', 'Bb', 'D'] 48 [3, 8, 10, 14]
# our result:  ['C-minor-ninth-#5', 'Bb-dominant-11th-on-C', 'Eb-suspended-major-13th-on-C']
# mingus result:  []
# music21 commonName result:  lydian pentachord
# music21 chordSymb  result:  ('A-/CaddD,B-', 'major')
# pychord result:  []
# ---
# ['C', 'E', 'Gb', 'Bb', 'D'] 48 [4, 6, 10, 14]
# our result:  ['C-dominant-ninth-#11', 'Gb-dominant-seventh-#11-on-C', 'E-half-diminished-b13-on-C']
# mingus result:  ['Gbaug|C7b5', 'Gbaug|C7b5']
# music21 commonName result:  whole-tone pentachord
# music21 chordSymb  result:  ('D9#5/C', 'augmented-dominant-ninth')
# pychord result:  [<Chord: C9-5>]
# ---
# ['C', 'Eb', 'Gb', 'Bb', 'D'] 48 [3, 6, 10, 14]
# our result:  ['C-half-diminished-ninth', 'C-minor-ninth-b5', 'Eb-minor-major-seventh-on-C', 'Eb-minor-sixth-major-seventh-on-C', 'Eb-minor-13th-major-seventh-on-C']
# mingus result:  ['Gbaug|Cdim', 'Gbaug|Cm7b5', 'Ebm/M7|Cdim', 'Ebm/M7|Cm7b5']
# music21 commonName result:  diminished-augmented ninth chord
# music21 chordSymb  result:  ('Cø9', 'half-diminished-ninth')
# pychord result:  []
# ---
# ['C', 'E', 'G', 'A', 'D'] 48 [4, 7, 9, 14]
# our result:  ['C-major-sixth-ninth', 'D-suspended-seventh-on-C', 'A-minor-11th-on-C', 'A-suspended-seventh-on-C']
# mingus result:  ['C sixth ninth', 'Gsus2|CM', 'Gsus2|CM6']
# music21 commonName result:  major pentatonic
# music21 chordSymb  result:  ('Am7/CaddD', 'minor-seventh')
# pychord result:  [<Chord: C69>]
# ---
# ['C', 'Eb', 'G', 'A', 'D'] 48 [3, 7, 9, 14]
# our result:  ['C-minor-sixth-ninth', 'A-half-diminished-11th-on-C']
# mingus result:  ['Gsus2|Cm', 'Gsus2|Cm6']
# music21 commonName result:  Kumoi pentachord
# music21 chordSymb  result:  ('Aø7/CaddD', 'half-diminished-seventh')
# pychord result:  [<Chord: Cm69>]
# ---
# ['C', 'E', 'G#', 'A', 'D'] 48 [4, 8, 9, 14]
# our result:  ['A-minor-11th-major-seventh-on-C', 'A-suspended-major-seventh-on-C']
# mingus result:  []
# music21 commonName result:  enigmatic pentachord
# music21 chordSymb  result:  ('AmM7/CaddD', 'minor-major-seventh')
# pychord result:  []
# ---
# ['C', 'Eb', 'G#', 'A', 'D'] 48 [3, 8, 9, 14]
# our result:  ['C-minor-sixth-ninth-#5']
# mingus result:  []
# music21 commonName result:  Balinese pentachord
# music21 chordSymb  result:  ('A-/CaddD,A', 'major')
# pychord result:  []
# ---
# ['C', 'E', 'Gb', 'A', 'D'] 48 [4, 6, 9, 14]
# our result:  ['C-major-sixth-ninth-b5', 'D-dominant-ninth-on-C', 'Gb-half-diminished-b13-on-C']
# mingus result:  []
# music21 commonName result:  dominant-ninth
# music21 chordSymb  result:  ('D9/C', 'dominant-ninth')
# pychord result:  []
# ---
# ['C', 'Eb', 'Gb', 'A', 'D'] 48 [3, 6, 9, 14]
# our result:  ['C-diminished-9', 'C-minor-sixth-ninth-b5', 'C-diminished-ninth', 'D-dominant-seventh-b9-on-C', 'Eb-diminished-major-seventh-on-C']
# mingus result:  []
# music21 commonName result:  flat-ninth pentachord
# music21 chordSymb  result:  ('Ao7/CaddD', 'diminished-seventh')
# pychord result:  []
# ---

# %%
chords_to_test = [
    ["C","G","E"],
    ["C","G","E","G","C","E"],
    ["E","G","C"],
    ["C","E","F"],
    ["C","E","F#"],
    ["C","E","F#","G"],
    ["C","E","G","E","G#"],
    ["C","Bb","Eb","E","Ab"],
    ["G","B","Eb","F","Bb"],
    ["C","E","G","B","D","F#","A"],
    ["C","E","B","D","F#","A"],
    ["C","E","B","D","A"],
    ["C","E","B","D"],
    ["C","E","A","B","D"],
    ["C","Eb","A","B","D"],
    ["C","A","D","F"],
    ["C","Eb","G","Bb","D"],
    ["Db","Eb","Gb","Ab","Bb"],
    ["C","Db","Ab"],
    ["C","E","A","Bb","D"],
    ["C","Bb","D","E","A"],
    ["C","B","E","G","A"],
    ["C","G","D","E","A"],
    ["C","E","A","D","F#"],
    ["G","F","A","C","E"],
    ["C","G","B","D","F"],
    ["C","E","F#","Bb","D","F#"],
    ["C","E","G#","Bb","D","F#"],
    ["C","E","F#","Bb","F#"],
    ["C","E","G#","Bb","F#"],
    ["C","E","G#","Bb","D","F#"],
    ["C","E","G","D","F#","A"],
    ["C","E","G","D","F#"],
    ["C","E","G","A","D","F#"],
    ["C","E","G","D","F#","A"],
    ["C","E","F#"],
    ["C","E","D","F#"],
    ["C","D","E","F#"],
    ["C","E","F#","G"],
    ["C","D","E","G"],
    ["C","E","G","D","F#","G#"],
    ["C","B","D","F"],
    ["C","E","G#","B"],
    ["C","E","G#","B","D"],
    ["C","E","G#","B","D","F#"],
    ["C","E","G#","B","D","F","F#"],
    ["C","Eb","E","G#","B","D","F#"],
    ["C","E","F#","G#","B","D","F"],
    ["C","Eb","A","D"],
    ["C","G","Bb"],
    ["C","Eb","F","D"],
    ["C","E","G","B","Ab"],
    ["C","E","G","B","Db","Ab"],
    ["C","E","G#","B","Db","Ab"],
    ["C","E","G","Bb","D#","Ab"],
    ["C","Eb","Gb","Bb","D","F"],
    ["C","Eb","Gb","Bb","D"],
    ["C","Eb","Gb","D"],
    ["C","F","Gb","A"],
    ["F","Gb","A","C"],
    ["C","Eb","Gb","Bb"],
    ["C","F","Gb","Bb"],
    ["C","E","F#","B"],
    ["C","F","G","Bb","Db"],
    ["F","Eb","A","C#","F#","Bb"],
    ["C","G","B","D"],
    ["C","G","B","D","F"],
    ["E","G","B","C"],
    ["E","F","G","B"],
    ["G","Bb","E"],
    
    ["C","C#","D","D#","E","F","G","G#","A"],
]
test_chords(chords_to_test, list_all = False)
# Out:
# ['C', 'G', 'E'] 48 [4, 7]
# our result:  ['C-major']
# mingus result:  []
# music21 commonName result:  major triad
# music21 chordSymb  result:  ('C', 'major')
# pychord result:  []
# ---
# ['C', 'G', 'E', 'G', 'C', 'E'] 48 [4, 7]
# our result:  ['C-major']
# mingus result:  []
# music21 commonName result:  major triad
# music21 chordSymb  result:  ('C', 'major')
# pychord result:  []
# ---
# ['E', 'G', 'C'] 52 [3, 8]
# our result:  ['C-major-on-E']
# mingus result:  ['C major triad, first inversion']
# music21 commonName result:  major triad
# music21 chordSymb  result:  ('C/E', 'major')
# pychord result:  [<Chord: C/E>]
# ---
# ['C', 'E', 'F'] 48 [4, 5]
# our result:  ['F-major-seventh-on-C']
# mingus result:  ['F major seventh, first inversion']
# music21 commonName result:  incomplete major-seventh chord
# music21 chordSymb  result:  ('Fpower/CaddE', 'power')
# pychord result:  []
# ---
# ['C', 'E', 'F#'] 48 [4, 6]
# our result:  ['C-major-b5']
# mingus result:  []
# music21 commonName result:  incomplete half-diminished seventh chord
# music21 chordSymb  result:  ('Chord Symbol Cannot Be Identified', '')
# pychord result:  [<Chord: C(b5)>]
# ---
# ['C', 'E', 'F#', 'G'] 48 [4, 6, 7]
# our result:  ['C-major-#4']
# mingus result:  []
# music21 commonName result:  all-interval tetrachord
# music21 chordSymb  result:  ('CaddF#', 'major')
# pychord result:  []
# ---
# ['C', 'E', 'G', 'E', 'G#'] 48 [4, 7, 20]
# our result:  ['Ab-augmented-major-seventh-on-C']
# mingus result:  []
# music21 commonName result:  augmented major tetrachord
# music21 chordSymb  result:  ('CaddG#', 'major')
# pychord result:  []
# ---
# ['C', 'Bb', 'Eb', 'E', 'Ab'] 48 [3, 4, 10, 20]
# our result:  ['C-alt']
# mingus result:  []
# music21 commonName result:  enigmatic pentachord
# music21 chordSymb  result:  ('F-+M7/CaddB-', 'augmented-major-seventh')
# pychord result:  []
# ---
# ['G', 'B', 'Eb', 'F', 'Bb'] 55 [3, 4, 8, 10]
# our result:  ['G-alt']
# mingus result:  []
# music21 commonName result:  enigmatic pentachord
# music21 chordSymb  result:  ('Chord Symbol Cannot Be Identified', '')
# pychord result:  [<Chord: G7#9#5>]
# ---
# ['C', 'E', 'G', 'B', 'D', 'F#', 'A'] 48 [4, 7, 11, 14, 18, 21]
# our result:  ['C-major-13th-#11']
# can only concatenate str (not "NoneType") to str
# music21 commonName result:  major scale
# music21 chordSymb  result:  ('CM9addA,F#', 'major-ninth')
# pychord result:  []
# ---
# ['C', 'E', 'B', 'D', 'F#', 'A'] 48 [4, 11, 14, 18, 21]
# our result:  ['C-major-13th-#11']
# mingus result:  ['D dominant thirteenth, third inversion', 'DM|CM7', 'Bm7|CM7']
# music21 commonName result:  dorian hexachord
# music21 chordSymb  result:  ('Bm7/CaddE', 'minor-seventh')
# pychord result:  [<Chord: D13/C>]
# ---
# ['C', 'E', 'B', 'D', 'A'] 48 [4, 11, 14, 21]
# our result:  ['C-major-13th']
# mingus result:  ['Bm7|CM7', 'E11|CM7']
# music21 commonName result:  dorian pentachord
# music21 chordSymb  result:  ('Am/CaddD,B', 'minor')
# pychord result:  []
# ---
# ['C', 'E', 'B', 'D'] 48 [4, 11, 14]
# our result:  ['C-major-ninth']
# mingus result:  ['Em7|CM7']
# music21 commonName result:  phrygian tetrachord
# music21 chordSymb  result:  ('CM9', 'major-ninth')
# pychord result:  []
# ---
# ['C', 'E', 'A', 'B', 'D'] 48 [4, 9, 11, 14]
# our result:  ['C-major-sixth-ninth']
# mingus result:  ['Esus47|CM6']
# music21 commonName result:  dorian pentachord
# music21 chordSymb  result:  ('Am/CaddD,B', 'minor')
# pychord result:  []
# ---
# ['C', 'Eb', 'A', 'B', 'D'] 48 [3, 9, 11, 14]
# our result:  ['C-minor-sixth-ninth-major-seventh']
# mingus result:  []
# music21 commonName result:  alternating pentachord
# music21 chordSymb  result:  ('Adim/CaddD,C-', 'diminished')
# pychord result:  []
# ---
# ['C', 'A', 'D', 'F'] 48 [9, 14, 17]
# our result:  ['D-minor-seventh-on-C']
# mingus result:  []
# music21 commonName result:  minor seventh chord
# music21 chordSymb  result:  ('Dm7/C', 'minor-seventh')
# pychord result:  []
# ---
# ['C', 'Eb', 'G', 'Bb', 'D'] 48 [3, 7, 10, 14]
# our result:  ['Eb-major-seventh-on-C']
# mingus result:  ['C minor ninth', 'Gm|Cm', 'Gm|Cm7', 'EbM7|Cm', 'EbM7|Cm7']
# music21 commonName result:  minor-ninth chord
# music21 chordSymb  result:  ('Cm9', 'minor-ninth')
# pychord result:  [<Chord: Cm9>]
# ---
# ['Db', 'Eb', 'Gb', 'Ab', 'Bb'] 49 [2, 5, 7, 9]
# our result:  ['Ab-suspended-seventh-on-Db']
# mingus result:  []
# music21 commonName result:  major pentatonic
# music21 chordSymb  result:  ('D#m7/C#addG#', 'minor-seventh')
# pychord result:  []
# ---
# ['C', 'Db', 'Ab'] 48 [1, 8]
# our result:  ['Db-major-seventh-on-C']
# mingus result:  ['Db major seventh, second inversion']
# music21 commonName result:  incomplete major-seventh chord
# music21 chordSymb  result:  ('D-power/C', 'power')
# pychord result:  []
# ---
# ['C', 'E', 'A', 'Bb', 'D'] 48 [4, 9, 10, 14]
# our result:  ['C-dominant-13th']
# mingus result:  []
# music21 commonName result:  phrygian pentachord
# music21 chordSymb  result:  ('Am/CaddD,B-', 'minor')
# pychord result:  []
# ---
# ['C', 'Bb', 'D', 'E', 'A'] 48 [4, 10, 14, 21]
# our result:  ['C-dominant-13th']
# mingus result:  []
# music21 commonName result:  phrygian pentachord
# music21 chordSymb  result:  ('Am/CaddD,B-', 'minor')
# pychord result:  []
# ---
# ['C', 'B', 'E', 'G', 'A'] 48 [4, 7, 11, 21]
# our result:  ['C-major-13th']
# mingus result:  []
# music21 commonName result:  minor-ninth chord
# music21 chordSymb  result:  ('Am9/C', 'minor-ninth')
# pychord result:  []
# ---
# ['C', 'G', 'D', 'E', 'A'] 48 [4, 7, 14, 21]
# our result:  ['C-major-sixth-ninth']
# mingus result:  []
# music21 commonName result:  major pentatonic
# music21 chordSymb  result:  ('Am7/CaddD', 'minor-seventh')
# pychord result:  []
# ---
# ['C', 'E', 'A', 'D', 'F#'] 48 [4, 9, 14, 18]
# our result:  ['Gb-half-diminished-b13-on-C']
# mingus result:  []
# music21 commonName result:  dominant-ninth
# music21 chordSymb  result:  ('D9/C', 'dominant-ninth')
# pychord result:  []
# ---
# ['G', 'F', 'A', 'C', 'E'] 55 [10, 14, 17, 21]
# our result:  ['F-major-seventh-on-G']
# can only concatenate str (not "NoneType") to str
# music21 commonName result:  major-ninth chord
# music21 chordSymb  result:  ('FM9/G', 'major-ninth')
# pychord result:  [<Chord: FM9/G>]
# ---
# ['C', 'G', 'B', 'D', 'F'] 48 [7, 11, 14, 17]
# our result:  ['G-dominant-seventh-on-C']
# mingus result:  ['Bdim|CM7', 'G7|CM7']
# music21 commonName result:  Kumoi pentachord
# music21 chordSymb  result:  ('G7/C', 'dominant-seventh')
# pychord result:  []
# ---
# ['C', 'E', 'F#', 'Bb', 'D', 'F#'] 48 [4, 6, 10, 14]
# our result:  ['Gb-dominant-seventh-#11-on-C']
# mingus result:  []
# music21 commonName result:  whole-tone pentachord
# music21 chordSymb  result:  ('D9#5/C', 'augmented-dominant-ninth')
# pychord result:  []
# ---
# ['C', 'E', 'G#', 'Bb', 'D', 'F#'] 48 [4, 8, 10, 14, 18]
# our result:  ['Bb-dominant-seventh-#11-on-C']
# mingus result:  ['Bbaug|Caug', 'Bbaug|Cm7+']
# music21 commonName result:  whole tone scale
# music21 chordSymb  result:  ('D9#5/CaddG#', 'augmented-dominant-ninth')
# pychord result:  []
# ---
# ['C', 'E', 'F#', 'Bb', 'F#'] 48 [4, 6, 10]
# our result:  ['C-dominant-seventh-b5']
# mingus result:  []
# music21 commonName result:  French augmented sixth chord
# music21 chordSymb  result:  ('F#dom7dim5/C', 'seventh-flat-five')
# pychord result:  []
# ---
# ['C', 'E', 'G#', 'Bb', 'F#'] 48 [4, 8, 10, 18]
# our result:  ['C-alt']
# mingus result:  []
# music21 commonName result:  whole-tone pentachord
# music21 chordSymb  result:  ('F#dom7dim5/CaddG#', 'seventh-flat-five')
# pychord result:  []
# ---
# ['C', 'E', 'G#', 'Bb', 'D', 'F#'] 48 [4, 8, 10, 14, 18]
# our result:  ['Bb-dominant-seventh-#11-on-C']
# mingus result:  ['Bbaug|Caug', 'Bbaug|Cm7+']
# music21 commonName result:  whole tone scale
# music21 chordSymb  result:  ('D9#5/CaddG#', 'augmented-dominant-ninth')
# pychord result:  []
# ---
# ['C', 'E', 'G', 'D', 'F#', 'A'] 48 [4, 7, 14, 18, 21]
# our result:  ['A-minor-13th-on-C']
# mingus result:  ['D eleventh, third inversion', 'DM|CM']
# music21 commonName result:  dominant-eleventh
# music21 chordSymb  result:  ('D11/C', 'dominant-11th')
# pychord result:  []
# ---
# ['C', 'E', 'G', 'D', 'F#'] 48 [4, 7, 14, 18]
# our result:  ['C-major-#4-9']
# mingus result:  ['GM7|CM']
# music21 commonName result:  lydian pentachord
# music21 chordSymb  result:  ('CaddD,F#', 'major')
# pychord result:  []
# ---
# ['C', 'E', 'G', 'A', 'D', 'F#'] 48 [4, 7, 9, 14, 18]
# our result:  ['D-dominant-11th-on-C']
# mingus result:  []
# music21 commonName result:  dominant-eleventh
# music21 chordSymb  result:  ('D11/C', 'dominant-11th')
# pychord result:  []
# ---
# ['C', 'E', 'G', 'D', 'F#', 'A'] 48 [4, 7, 14, 18, 21]
# our result:  ['A-minor-13th-on-C']
# mingus result:  ['D eleventh, third inversion', 'DM|CM']
# music21 commonName result:  dominant-eleventh
# music21 chordSymb  result:  ('D11/C', 'dominant-11th')
# pychord result:  []
# ---
# ['C', 'E', 'F#'] 48 [4, 6]
# our result:  ['C-major-b5']
# mingus result:  []
# music21 commonName result:  incomplete half-diminished seventh chord
# music21 chordSymb  result:  ('Chord Symbol Cannot Be Identified', '')
# pychord result:  [<Chord: C(b5)>]
# ---
# ['C', 'E', 'D', 'F#'] 48 [4, 14, 18]
# our result:  ['C-major-#4-9']
# mingus result:  []
# music21 commonName result:  whole-tone tetramirror
# music21 chordSymb  result:  ('D9/C', 'dominant-ninth')
# pychord result:  []
# ---
# ['C', 'D', 'E', 'F#'] 48 [2, 4, 6]
# our result:  ['C-major-#4-2']
# mingus result:  []
# music21 commonName result:  whole-tone tetramirror
# music21 chordSymb  result:  ('D9/C', 'dominant-ninth')
# pychord result:  []
# ---
# ['C', 'E', 'F#', 'G'] 48 [4, 6, 7]
# our result:  ['C-major-#4']
# mingus result:  []
# music21 commonName result:  all-interval tetrachord
# music21 chordSymb  result:  ('CaddF#', 'major')
# pychord result:  []
# ---
# ['C', 'D', 'E', 'G'] 48 [2, 4, 7]
# our result:  ['C-major-2']
# mingus result:  []
# music21 commonName result:  major-second major tetrachord
# music21 chordSymb  result:  ('CaddD', 'major')
# pychord result:  [<Chord: Em7+5/C>]
# ---
# ['C', 'E', 'G', 'D', 'F#', 'G#'] 48 [4, 7, 14, 18, 20]
# our result:  ['D-dominant-11th-#5-on-C']
# mingus result:  []
# music21 commonName result:  combinatorial I (I5)
# music21 chordSymb  result:  ('Ddom7dim5/CaddG,E', 'seventh-flat-five')
# pychord result:  []
# ---
# ['C', 'B', 'D', 'F'] 48 [11, 14, 17]
# our result:  ['B-diminished-on-C']
# mingus result:  []
# music21 commonName result:  minor-second diminished tetrachord
# music21 chordSymb  result:  ('Bdim/C', 'diminished')
# pychord result:  []
# ---
# ['C', 'E', 'G#', 'B'] 48 [4, 8, 11]
# our result:  ['C-augmented-major-seventh']
# mingus result:  ['C augmented major seventh', 'EM|Caug']
# music21 commonName result:  augmented major tetrachord
# music21 chordSymb  result:  ('C+M7', 'augmented-major-seventh')
# pychord result:  [<Chord: CM7+5>]
# ---
# ['C', 'E', 'G#', 'B', 'D'] 48 [4, 8, 11, 14]
# our result:  ['E-dominant-seventh-on-C']
# mingus result:  ['G#dim|Caug', 'G#dim|CM7+', 'E7|Caug', 'E7|CM7+']
# music21 commonName result:  augmented-diminished ninth chord
# music21 chordSymb  result:  ('C+M9', 'augmented-major-ninth')
# pychord result:  [<Chord: E7-13/C>]
# ---
# ['C', 'E', 'G#', 'B', 'D', 'F#'] 48 [4, 8, 11, 14, 18]
# our result:  ['C-augmented-major-#11']
# mingus result:  ['Bm|Caug', 'Bm|CM7+', 'G#m7b5|Caug', 'G#m7b5|CM7+', 'E9|Caug', 'E9|CM7+']
# music21 commonName result:  Scriabin's Mystic-chord
# music21 chordSymb  result:  ('C+M9addF#', 'augmented-major-ninth')
# pychord result:  []
# ---
# ['C', 'E', 'G#', 'B', 'D', 'F', 'F#'] 48 [4, 8, 11, 14, 17, 18]
# our result:  ['C-augmented-major-11th-#11']
# mingus result:  []
# music21 commonName result:  forte class 7-28A
# music21 chordSymb  result:  ('C+M11addF#', 'augmented-major-11th')
# pychord result:  []
# ---
# ['C', 'Eb', 'E', 'G#', 'B', 'D', 'F#'] 48 [3, 4, 8, 11, 14, 18]
# our result:  ['C-augmented-major-#11-#9']
# mingus result:  []
# music21 commonName result:  forte class 7-26A
# music21 chordSymb  result:  ('Ddom7dim5/CaddE,C-,E-', 'seventh-flat-five')
# pychord result:  []
# ---
# ['C', 'E', 'F#', 'G#', 'B', 'D', 'F'] 48 [4, 6, 8, 11, 14, 17]
# our result:  ['C-augmented-major-11th-#11']
# mingus result:  []
# music21 commonName result:  forte class 7-28A
# music21 chordSymb  result:  ('C+M9addF,F#', 'augmented-major-ninth')
# pychord result:  []
# ---
# ['C', 'Eb', 'A', 'D'] 48 [3, 9, 14]
# our result:  ['C-minor-sixth-ninth']
# mingus result:  []
# music21 commonName result:  perfect-fourth diminished tetrachord
# music21 chordSymb  result:  ('Adim/CaddD', 'diminished')
# pychord result:  []
# ---
# ['C', 'G', 'Bb'] 48 [7, 10]
# our result:  ['C-suspended-seventh']
# mingus result:  ['C minor seventh']
# music21 commonName result:  incomplete dominant-seventh chord
# music21 chordSymb  result:  ('CpoweraddB-', 'power')
# pychord result:  []
# ---
# ['C', 'Eb', 'F', 'D'] 48 [3, 5, 14]
# our result:  ['C-minor-4-9']
# mingus result:  []
# music21 commonName result:  minor tetramirror
# music21 chordSymb  result:  ('Chord Symbol Cannot Be Identified', '')
# pychord result:  []
# ---
# ['C', 'E', 'G', 'B', 'Ab'] 48 [4, 7, 11, 20]
# our result:  ['C-major-seventh-b13']
# mingus result:  []
# music21 commonName result:  Lebanese pentachord
# music21 chordSymb  result:  ('Cmaj7addG#', 'major-seventh')
# pychord result:  []
# ---
# ['C', 'E', 'G', 'B', 'Db', 'Ab'] 48 [4, 7, 11, 13, 20]
# our result:  ['Db-minor-#11-on-C']
# mingus result:  []
# music21 commonName result:  quasi raga Bauli
# music21 chordSymb  result:  ('Cmaj7addG#,C#', 'major-seventh')
# pychord result:  []
# ---
# ['C', 'E', 'G#', 'B', 'Db', 'Ab'] 48 [4, 8, 11, 13]
# our result:  ['E-major-sixth-on-C']
# mingus result:  []
# music21 commonName result:  center-cluster pentamirror
# music21 chordSymb  result:  ('C+M7addC#', 'augmented-major-seventh')
# pychord result:  []
# ---
# ['C', 'E', 'G', 'Bb', 'D#', 'Ab'] 48 [3, 4, 7, 10, 20]
# our result:  ['C-alt']
# mingus result:  []
# music21 commonName result:  combinatorial I (I7)
# music21 chordSymb  result:  ('A-+M9/CaddE-', 'augmented-major-ninth')
# pychord result:  []
# ---
# ['C', 'Eb', 'Gb', 'Bb', 'D', 'F'] 48 [3, 6, 10, 14, 17]
# our result:  ['C-half-diminished-11th']
# mingus result:  ['BbM|Cdim', 'BbM|Cm7b5', 'GbM7+|Cdim', 'GbM7+|Cm7b5']
# music21 commonName result:  melodic-minor hexachord
# music21 chordSymb  result:  ('Cø9addF', 'half-diminished-ninth')
# pychord result:  []
# ---
# ['C', 'Eb', 'Gb', 'Bb', 'D'] 48 [3, 6, 10, 14]
# our result:  ['Eb-minor-major-seventh-on-C']
# mingus result:  ['Gbaug|Cdim', 'Gbaug|Cm7b5', 'Ebm/M7|Cdim', 'Ebm/M7|Cm7b5']
# music21 commonName result:  diminished-augmented ninth chord
# music21 chordSymb  result:  ('Cø9', 'half-diminished-ninth')
# pychord result:  []
# ---
# ['C', 'Eb', 'Gb', 'D'] 48 [3, 6, 14]
# our result:  ['Eb-minor-major-seventh-on-C']
# mingus result:  ['Ebm/M7|Cdim']
# music21 commonName result:  harmonic minor tetrachord
# music21 chordSymb  result:  ('CdimaddD', 'diminished')
# pychord result:  []
# ---
# ['C', 'F', 'Gb', 'A'] 48 [5, 6, 9]
# our result:  ['Gb-diminished-major-seventh-on-C']
# mingus result:  []
# music21 commonName result:  major-diminished tetrachord
# music21 chordSymb  result:  ('F/CaddF#', 'major')
# pychord result:  []
# ---
# ['F', 'Gb', 'A', 'C'] 53 [1, 4, 7]
# our result:  ['Gb-diminished-on-F']
# mingus result:  []
# music21 commonName result:  major-diminished tetrachord
# music21 chordSymb  result:  ('FaddF#', 'major')
# pychord result:  []
# ---
# ['C', 'Eb', 'Gb', 'Bb'] 48 [3, 6, 10]
# our result:  ['C-half-diminished-seventh']
# mingus result:  ['C half diminished seventh', 'Eb minor sixth, third inversion', 'Ebm|Cdim']
# music21 commonName result:  half-diminished seventh chord
# music21 chordSymb  result:  ('Cø7', 'half-diminished-seventh')
# pychord result:  [<Chord: Cm7-5>, <Chord: Ebm6/C>]
# ---
# ['C', 'F', 'Gb', 'Bb'] 48 [5, 6, 10]
# our result:  ['C-half-diminished-11th']
# mingus result:  []
# music21 commonName result:  minor-second quartal tetrachord
# music21 chordSymb  result:  ('Chord Symbol Cannot Be Identified', '')
# pychord result:  []
# ---
# ['C', 'E', 'F#', 'B'] 48 [4, 6, 11]
# our result:  ['Gb-half-diminished-11th-on-C']
# mingus result:  []
# music21 commonName result:  minor-second quartal tetrachord
# music21 chordSymb  result:  ('Chord Symbol Cannot Be Identified', '')
# pychord result:  []
# ---
# ['C', 'F', 'G', 'Bb', 'Db'] 48 [5, 7, 10, 13]
# our result:  ['Db-major-13th-#11-on-C']
# mingus result:  ['Gdim|Csus4', 'Gdim|Csus47']
# music21 commonName result:  Kumoi pentachord
# music21 chordSymb  result:  ('Gø7/C', 'half-diminished-seventh')
# pychord result:  []
# ---
# ['F', 'Eb', 'A', 'C#', 'F#', 'Bb'] 53 [4, 10, 13, 17, 20]
# our result:  ['Eb-minor-#11-on-F']
# mingus result:  []
# music21 commonName result:  combinatorial I (I11)
# music21 chordSymb  result:  ('F7+addA#,F#', 'augmented-seventh')
# pychord result:  []
# ---
# ['C', 'G', 'B', 'D'] 48 [7, 11, 14]
# our result:  ['G-major-on-C']
# mingus result:  ['GM|CM7']
# music21 commonName result:  perfect-fourth major tetrachord
# music21 chordSymb  result:  ('G/C', 'major')
# pychord result:  [<Chord: Gadd11/C>]
# ---
# ['C', 'G', 'B', 'D', 'F'] 48 [7, 11, 14, 17]
# our result:  ['G-dominant-seventh-on-C']
# mingus result:  ['Bdim|CM7', 'G7|CM7']
# music21 commonName result:  Kumoi pentachord
# music21 chordSymb  result:  ('G7/C', 'dominant-seventh')
# pychord result:  []
# ---
# ['E', 'G', 'B', 'C'] 52 [3, 7, 8]
# our result:  ['C-major-seventh-on-E']
# mingus result:  ['C major seventh, first inversion']
# music21 commonName result:  major seventh chord
# music21 chordSymb  result:  ('Cmaj7/E', 'major-seventh')
# pychord result:  [<Chord: CM7/E>]
# ---
# ['E', 'F', 'G', 'B'] 52 [1, 3, 7]
# our result:  ['E-minor-b2']
# mingus result:  []
# music21 commonName result:  all-interval tetrachord
# music21 chordSymb  result:  ('EmaddF', 'minor')
# pychord result:  []
# ---
# ['G', 'Bb', 'E'] 55 [3, 9]
# our result:  ['G-minor-sixth']
# mingus result:  ['G minor sixth', 'E diminished triad, first inversion']
# music21 commonName result:  diminished triad
# music21 chordSymb  result:  ('Edim/G', 'diminished')
# pychord result:  [<Chord: Edim/G>]
# ---
# ['C', 'C#', 'D', 'D#', 'E', 'F', 'G', 'G#', 'A'] 48 [1, 2, 3, 4, 5, 7, 8, 9]
# our result:  ['C-unknown-on-C']
# mingus result:  []
# music21 commonName result:  forte class 9-4A
# music21 chordSymb  result:  ('D-M9/CaddD,G,E,A', 'major-ninth')
# pychord result:  []
# ---

# %%
test_chords(chords_to_test, detect_inversion = True, list_all = True)
# Out:
# ['C', 'G', 'E'] 48 [4, 7]
# our result:  ['C-major']
# mingus result:  []
# music21 commonName result:  major triad
# music21 chordSymb  result:  ('C', 'major')
# pychord result:  []
# ---
# ['C', 'G', 'E', 'G', 'C', 'E'] 48 [4, 7]
# our result:  ['C-major']
# mingus result:  []
# music21 commonName result:  major triad
# music21 chordSymb  result:  ('C', 'major')
# pychord result:  []
# ---
# ['E', 'G', 'C'] 52 [3, 8]
# our result:  ['C-major-on-E']
# mingus result:  ['C major triad, first inversion']
# music21 commonName result:  major triad
# music21 chordSymb  result:  ('C/E', 'major')
# pychord result:  [<Chord: C/E>]
# ---
# ['C', 'E', 'F'] 48 [4, 5]
# our result:  ['C-major-4', 'F-major-seventh-on-C', 'F-suspended-major-seventh-on-C']
# mingus result:  ['F major seventh, first inversion']
# music21 commonName result:  incomplete major-seventh chord
# music21 chordSymb  result:  ('Fpower/CaddE', 'power')
# pychord result:  []
# ---
# ['C', 'E', 'F#'] 48 [4, 6]
# our result:  ['C-major-b5', 'Gb-half-diminished-seventh-on-C']
# mingus result:  []
# music21 commonName result:  incomplete half-diminished seventh chord
# music21 chordSymb  result:  ('Chord Symbol Cannot Be Identified', '')
# pychord result:  [<Chord: C(b5)>]
# ---
# ['C', 'E', 'F#', 'G'] 48 [4, 6, 7]
# our result:  ['C-major-#4', 'C-major-b5', 'G-suspended-major-13th-on-C']
# mingus result:  []
# music21 commonName result:  all-interval tetrachord
# music21 chordSymb  result:  ('CaddF#', 'major')
# pychord result:  []
# ---
# ['C', 'E', 'G', 'E', 'G#'] 48 [4, 7, 20]
# our result:  ['C-major-b13', 'Ab-augmented-major-seventh-on-C']
# mingus result:  []
# music21 commonName result:  augmented major tetrachord
# music21 chordSymb  result:  ('CaddG#', 'major')
# pychord result:  []
# ---
# ['C', 'Bb', 'Eb', 'E', 'Ab'] 48 [3, 4, 10, 20]
# our result:  ['C-alt', 'C-minor-seventh-major3-b13', 'Bb-half-diminished-11th-on-C']
# mingus result:  []
# music21 commonName result:  enigmatic pentachord
# music21 chordSymb  result:  ('F-+M7/CaddB-', 'augmented-major-seventh')
# pychord result:  []
# ---
# ['G', 'B', 'Eb', 'F', 'Bb'] 55 [3, 4, 8, 10]
# our result:  ['G-alt', 'G-minor-seventh-major3-#5', 'F-half-diminished-11th-on-G', 'B-augmented-major-#11-on-G']
# mingus result:  []
# music21 commonName result:  enigmatic pentachord
# music21 chordSymb  result:  ('Chord Symbol Cannot Be Identified', '')
# pychord result:  [<Chord: G7#9#5>]
# ---
# ['C', 'E', 'G', 'B', 'D', 'F#', 'A'] 48 [4, 7, 11, 14, 18, 21]
# our result:  ['C-major-13th-#11', 'A-minor-13th-on-C', 'D-dominant-13th-on-C', 'G-major-13th-on-C']
# can only concatenate str (not "NoneType") to str
# music21 commonName result:  major scale
# music21 chordSymb  result:  ('CM9addA,F#', 'major-ninth')
# pychord result:  []
# ---
# ['C', 'E', 'B', 'D', 'F#', 'A'] 48 [4, 11, 14, 18, 21]
# our result:  ['C-major-13th-#11', 'Gb-half-diminished-b13-on-C', 'D-dominant-13th-on-C']
# mingus result:  ['D dominant thirteenth, third inversion', 'DM|CM7', 'Bm7|CM7']
# music21 commonName result:  dorian hexachord
# music21 chordSymb  result:  ('Bm7/CaddE', 'minor-seventh')
# pychord result:  [<Chord: D13/C>]
# ---
# ['C', 'E', 'B', 'D', 'A'] 48 [4, 11, 14, 21]
# our result:  ['C-major-13th', 'D-suspended-13th-on-C']
# mingus result:  ['Bm7|CM7', 'E11|CM7']
# music21 commonName result:  dorian pentachord
# music21 chordSymb  result:  ('Am/CaddD,B', 'minor')
# pychord result:  []
# ---
# ['C', 'E', 'B', 'D'] 48 [4, 11, 14]
# our result:  ['C-major-ninth']
# mingus result:  ['Em7|CM7']
# music21 commonName result:  phrygian tetrachord
# music21 chordSymb  result:  ('CM9', 'major-ninth')
# pychord result:  []
# ---
# ['C', 'E', 'A', 'B', 'D'] 48 [4, 9, 11, 14]
# our result:  ['C-major-sixth-ninth', 'D-suspended-13th-on-C']
# mingus result:  ['Esus47|CM6']
# music21 commonName result:  dorian pentachord
# music21 chordSymb  result:  ('Am/CaddD,B', 'minor')
# pychord result:  []
# ---
# ['C', 'Eb', 'A', 'B', 'D'] 48 [3, 9, 11, 14]
# our result:  ['C-minor-sixth-ninth-major-seventh', 'Eb-augmented-major-13th-#11-on-C']
# mingus result:  []
# music21 commonName result:  alternating pentachord
# music21 chordSymb  result:  ('Adim/CaddD,C-', 'diminished')
# pychord result:  []
# ---
# ['C', 'A', 'D', 'F'] 48 [9, 14, 17]
# our result:  ['D-minor-seventh-on-C']
# mingus result:  []
# music21 commonName result:  minor seventh chord
# music21 chordSymb  result:  ('Dm7/C', 'minor-seventh')
# pychord result:  []
# ---
# ['C', 'Eb', 'G', 'Bb', 'D'] 48 [3, 7, 10, 14]
# our result:  ['C-minor-ninth', 'Eb-major-seventh-on-C', 'Eb-major-13th-on-C']
# mingus result:  ['C minor ninth', 'Gm|Cm', 'Gm|Cm7', 'EbM7|Cm', 'EbM7|Cm7']
# music21 commonName result:  minor-ninth chord
# music21 chordSymb  result:  ('Cm9', 'minor-ninth')
# pychord result:  [<Chord: Cm9>]
# ---
# ['Db', 'Eb', 'Gb', 'Ab', 'Bb'] 49 [2, 5, 7, 9]
# our result:  ['Ab-suspended-seventh-on-Db', 'Gb-major-sixth-ninth-on-Db', 'Eb-minor-11th-on-Db']
# mingus result:  []
# music21 commonName result:  major pentatonic
# music21 chordSymb  result:  ('D#m7/C#addG#', 'minor-seventh')
# pychord result:  []
# ---
# ['C', 'Db', 'Ab'] 48 [1, 8]
# our result:  ['Ab-major-4-on-C', 'Db-major-seventh-on-C', 'Db-suspended-major-seventh-on-C']
# mingus result:  ['Db major seventh, second inversion']
# music21 commonName result:  incomplete major-seventh chord
# music21 chordSymb  result:  ('D-power/C', 'power')
# pychord result:  []
# ---
# ['C', 'E', 'A', 'Bb', 'D'] 48 [4, 9, 10, 14]
# our result:  ['C-dominant-13th', 'Bb-major-seventh-#11-on-C', 'E-half-diminished-b13-on-C']
# mingus result:  []
# music21 commonName result:  phrygian pentachord
# music21 chordSymb  result:  ('Am/CaddD,B-', 'minor')
# pychord result:  []
# ---
# ['C', 'Bb', 'D', 'E', 'A'] 48 [4, 10, 14, 21]
# our result:  ['C-dominant-13th', 'Bb-major-seventh-#11-on-C', 'E-half-diminished-b13-on-C']
# mingus result:  []
# music21 commonName result:  phrygian pentachord
# music21 chordSymb  result:  ('Am/CaddD,B-', 'minor')
# pychord result:  []
# ---
# ['C', 'B', 'E', 'G', 'A'] 48 [4, 7, 11, 21]
# our result:  ['C-major-13th', 'A-minor-ninth-on-C']
# mingus result:  []
# music21 commonName result:  minor-ninth chord
# music21 chordSymb  result:  ('Am9/C', 'minor-ninth')
# pychord result:  []
# ---
# ['C', 'G', 'D', 'E', 'A'] 48 [4, 7, 14, 21]
# our result:  ['C-major-sixth-ninth', 'A-minor-11th-on-C', 'D-suspended-seventh-on-C']
# mingus result:  []
# music21 commonName result:  major pentatonic
# music21 chordSymb  result:  ('Am7/CaddD', 'minor-seventh')
# pychord result:  []
# ---
# ['C', 'E', 'A', 'D', 'F#'] 48 [4, 9, 14, 18]
# our result:  ['C-major-sixth-#11', 'Gb-half-diminished-b13-on-C', 'D-dominant-ninth-on-C', 'A-minor-sixth-11th-on-C']
# mingus result:  []
# music21 commonName result:  dominant-ninth
# music21 chordSymb  result:  ('D9/C', 'dominant-ninth')
# pychord result:  []
# ---
# ['G', 'F', 'A', 'C', 'E'] 55 [10, 14, 17, 21]
# our result:  ['G-suspended-13th', 'F-major-seventh-on-G', 'F-major-ninth-on-G']
# can only concatenate str (not "NoneType") to str
# music21 commonName result:  major-ninth chord
# music21 chordSymb  result:  ('FM9/G', 'major-ninth')
# pychord result:  [<Chord: FM9/G>]
# ---
# ['C', 'G', 'B', 'D', 'F'] 48 [7, 11, 14, 17]
# our result:  ['C-suspended-major-seventh', 'G-dominant-seventh-on-C', 'D-minor-13th-on-C', 'G-dominant-11th-on-C']
# mingus result:  ['Bdim|CM7', 'G7|CM7']
# music21 commonName result:  Kumoi pentachord
# music21 chordSymb  result:  ('G7/C', 'dominant-seventh')
# pychord result:  []
# ---
# ['C', 'E', 'F#', 'Bb', 'D', 'F#'] 48 [4, 6, 10, 14]
# our result:  ['C-dominant-ninth-#11', 'Gb-dominant-seventh-#11-on-C', 'E-half-diminished-b13-on-C']
# mingus result:  []
# music21 commonName result:  whole-tone pentachord
# music21 chordSymb  result:  ('D9#5/C', 'augmented-dominant-ninth')
# pychord result:  []
# ---
# ['C', 'E', 'G#', 'Bb', 'D', 'F#'] 48 [4, 8, 10, 14, 18]
# our result:  ['C-dominant-seventh-#11-#5', 'Bb-dominant-seventh-#11-on-C']
# mingus result:  ['Bbaug|Caug', 'Bbaug|Cm7+']
# music21 commonName result:  whole tone scale
# music21 chordSymb  result:  ('D9#5/CaddG#', 'augmented-dominant-ninth')
# pychord result:  []
# ---
# ['C', 'E', 'F#', 'Bb', 'F#'] 48 [4, 6, 10]
# our result:  ['C-dominant-seventh-b5', 'Gb-dominant-seventh-b5-on-C']
# mingus result:  []
# music21 commonName result:  French augmented sixth chord
# music21 chordSymb  result:  ('F#dom7dim5/C', 'seventh-flat-five')
# pychord result:  []
# ---
# ['C', 'E', 'G#', 'Bb', 'F#'] 48 [4, 8, 10, 18]
# our result:  ['C-alt', 'C-dominant-seventh-#11-#5', 'Gb-dominant-ninth-#5-on-C', 'Bb-half-diminished-b13-on-C']
# mingus result:  []
# music21 commonName result:  whole-tone pentachord
# music21 chordSymb  result:  ('F#dom7dim5/CaddG#', 'seventh-flat-five')
# pychord result:  []
# ---
# ['C', 'E', 'G#', 'Bb', 'D', 'F#'] 48 [4, 8, 10, 14, 18]
# our result:  ['C-dominant-seventh-#11-#5', 'Bb-dominant-seventh-#11-on-C']
# mingus result:  ['Bbaug|Caug', 'Bbaug|Cm7+']
# music21 commonName result:  whole tone scale
# music21 chordSymb  result:  ('D9#5/CaddG#', 'augmented-dominant-ninth')
# pychord result:  []
# ---
# ['C', 'E', 'G', 'D', 'F#', 'A'] 48 [4, 7, 14, 18, 21]
# our result:  ['A-minor-13th-on-C', 'D-dominant-11th-on-C', 'G-major-13th-on-C', 'G-suspended-major-13th-on-C']
# mingus result:  ['D eleventh, third inversion', 'DM|CM']
# music21 commonName result:  dominant-eleventh
# music21 chordSymb  result:  ('D11/C', 'dominant-11th')
# pychord result:  []
# ---
# ['C', 'E', 'G', 'D', 'F#'] 48 [4, 7, 14, 18]
# our result:  ['C-major-#4-9', 'D-dominant-11th-on-C', 'G-major-13th-on-C', 'G-suspended-major-13th-on-C']
# mingus result:  ['GM7|CM']
# music21 commonName result:  lydian pentachord
# music21 chordSymb  result:  ('CaddD,F#', 'major')
# pychord result:  []
# ---
# ['C', 'E', 'G', 'A', 'D', 'F#'] 48 [4, 7, 9, 14, 18]
# our result:  ['C-major-sixth-#11', 'D-dominant-11th-on-C', 'A-minor-sixth-11th-on-C', 'A-suspended-13th-on-C', 'G-major-13th-on-C', 'G-suspended-major-13th-on-C']
# mingus result:  []
# music21 commonName result:  dominant-eleventh
# music21 chordSymb  result:  ('D11/C', 'dominant-11th')
# pychord result:  []
# ---
# ['C', 'E', 'G', 'D', 'F#', 'A'] 48 [4, 7, 14, 18, 21]
# our result:  ['A-minor-13th-on-C', 'D-dominant-11th-on-C', 'G-major-13th-on-C', 'G-suspended-major-13th-on-C']
# mingus result:  ['D eleventh, third inversion', 'DM|CM']
# music21 commonName result:  dominant-eleventh
# music21 chordSymb  result:  ('D11/C', 'dominant-11th')
# pychord result:  []
# ---
# ['C', 'E', 'F#'] 48 [4, 6]
# our result:  ['C-major-b5', 'Gb-half-diminished-seventh-on-C']
# mingus result:  []
# music21 commonName result:  incomplete half-diminished seventh chord
# music21 chordSymb  result:  ('Chord Symbol Cannot Be Identified', '')
# pychord result:  [<Chord: C(b5)>]
# ---
# ['C', 'E', 'D', 'F#'] 48 [4, 14, 18]
# our result:  ['C-major-#4-9', 'Gb-half-diminished-b13-on-C', 'D-dominant-ninth-on-C']
# mingus result:  []
# music21 commonName result:  whole-tone tetramirror
# music21 chordSymb  result:  ('D9/C', 'dominant-ninth')
# pychord result:  []
# ---
# ['C', 'D', 'E', 'F#'] 48 [2, 4, 6]
# our result:  ['C-major-#4-2', 'Gb-half-diminished-b13-on-C', 'D-dominant-ninth-on-C']
# mingus result:  []
# music21 commonName result:  whole-tone tetramirror
# music21 chordSymb  result:  ('D9/C', 'dominant-ninth')
# pychord result:  []
# ---
# ['C', 'E', 'F#', 'G'] 48 [4, 6, 7]
# our result:  ['C-major-#4', 'C-major-b5', 'G-suspended-major-13th-on-C']
# mingus result:  []
# music21 commonName result:  all-interval tetrachord
# music21 chordSymb  result:  ('CaddF#', 'major')
# pychord result:  []
# ---
# ['C', 'D', 'E', 'G'] 48 [2, 4, 7]
# our result:  ['C-major-2', 'D-suspended-seventh-on-C']
# mingus result:  []
# music21 commonName result:  major-second major tetrachord
# music21 chordSymb  result:  ('CaddD', 'major')
# pychord result:  [<Chord: Em7+5/C>]
# ---
# ['C', 'E', 'G', 'D', 'F#', 'G#'] 48 [4, 7, 14, 18, 20]
# our result:  ['Ab-augmented-major-#11-on-C', 'D-dominant-11th-#5-on-C']
# mingus result:  []
# music21 commonName result:  combinatorial I (I5)
# music21 chordSymb  result:  ('Ddom7dim5/CaddG,E', 'seventh-flat-five')
# pychord result:  []
# ---
# ['C', 'B', 'D', 'F'] 48 [11, 14, 17]
# our result:  ['C-suspended-major-seventh', 'B-diminished-on-C', 'D-minor-sixth-seventh-on-C', 'D-minor-13th-on-C']
# mingus result:  []
# music21 commonName result:  minor-second diminished tetrachord
# music21 chordSymb  result:  ('Bdim/C', 'diminished')
# pychord result:  []
# ---
# ['C', 'E', 'G#', 'B'] 48 [4, 8, 11]
# our result:  ['C-augmented-major-seventh', 'E-major-on-C']
# mingus result:  ['C augmented major seventh', 'EM|Caug']
# music21 commonName result:  augmented major tetrachord
# music21 chordSymb  result:  ('C+M7', 'augmented-major-seventh')
# pychord result:  [<Chord: CM7+5>]
# ---
# ['C', 'E', 'G#', 'B', 'D'] 48 [4, 8, 11, 14]
# our result:  ['C-augmented-major-ninth', 'E-dominant-seventh-on-C']
# mingus result:  ['G#dim|Caug', 'G#dim|CM7+', 'E7|Caug', 'E7|CM7+']
# music21 commonName result:  augmented-diminished ninth chord
# music21 chordSymb  result:  ('C+M9', 'augmented-major-ninth')
# pychord result:  [<Chord: E7-13/C>]
# ---
# ['C', 'E', 'G#', 'B', 'D', 'F#'] 48 [4, 8, 11, 14, 18]
# our result:  ['C-augmented-major-#11', 'Gb-half-diminished-b13-on-C', 'D-dominant-13th-#11-on-C']
# mingus result:  ['Bm|Caug', 'Bm|CM7+', 'G#m7b5|Caug', 'G#m7b5|CM7+', 'E9|Caug', 'E9|CM7+']
# music21 commonName result:  Scriabin's Mystic-chord
# music21 chordSymb  result:  ('C+M9addF#', 'augmented-major-ninth')
# pychord result:  []
# ---
# ['C', 'E', 'G#', 'B', 'D', 'F', 'F#'] 48 [4, 8, 11, 14, 17, 18]
# our result:  ['C-augmented-major-11th-#11']
# mingus result:  []
# music21 commonName result:  forte class 7-28A
# music21 chordSymb  result:  ('C+M11addF#', 'augmented-major-11th')
# pychord result:  []
# ---
# ['C', 'Eb', 'E', 'G#', 'B', 'D', 'F#'] 48 [3, 4, 8, 11, 14, 18]
# our result:  ['C-minor-major-seventh-#11-major3-#5', 'C-augmented-major-#11-#9', 'C-diminished-major-ninth-major3-b13']
# mingus result:  []
# music21 commonName result:  forte class 7-26A
# music21 chordSymb  result:  ('Ddom7dim5/CaddE,C-,E-', 'seventh-flat-five')
# pychord result:  []
# ---
# ['C', 'E', 'F#', 'G#', 'B', 'D', 'F'] 48 [4, 6, 8, 11, 14, 17]
# our result:  ['C-augmented-major-11th-#11']
# mingus result:  []
# music21 commonName result:  forte class 7-28A
# music21 chordSymb  result:  ('C+M9addF,F#', 'augmented-major-ninth')
# pychord result:  []
# ---
# ['C', 'Eb', 'A', 'D'] 48 [3, 9, 14]
# our result:  ['C-minor-sixth-ninth', 'Eb-diminished-major-seventh-on-C']
# mingus result:  []
# music21 commonName result:  perfect-fourth diminished tetrachord
# music21 chordSymb  result:  ('Adim/CaddD', 'diminished')
# pychord result:  []
# ---
# ['C', 'G', 'Bb'] 48 [7, 10]
# our result:  ['C-suspended-seventh', 'Bb-major-sixth-ninth-on-C', 'G-minor-4-on-C']
# mingus result:  ['C minor seventh']
# music21 commonName result:  incomplete dominant-seventh chord
# music21 chordSymb  result:  ('CpoweraddB-', 'power')
# pychord result:  []
# ---
# ['C', 'Eb', 'F', 'D'] 48 [3, 5, 14]
# our result:  ['C-minor-4-9', 'F-minor-sixth-seventh-on-C', 'F-minor-sixth-on-C', 'F-suspended-13th-on-C', 'Eb-major-13th-on-C']
# mingus result:  []
# music21 commonName result:  minor tetramirror
# music21 chordSymb  result:  ('Chord Symbol Cannot Be Identified', '')
# pychord result:  []
# ---
# ['C', 'E', 'G', 'B', 'Ab'] 48 [4, 7, 11, 20]
# our result:  ['C-major-seventh-b13']
# mingus result:  []
# music21 commonName result:  Lebanese pentachord
# music21 chordSymb  result:  ('Cmaj7addG#', 'major-seventh')
# pychord result:  []
# ---
# ['C', 'E', 'G', 'B', 'Db', 'Ab'] 48 [4, 7, 11, 13, 20]
# our result:  ['C-major-seventh-b9-b13', 'Db-minor-#11-on-C']
# mingus result:  []
# music21 commonName result:  quasi raga Bauli
# music21 chordSymb  result:  ('Cmaj7addG#,C#', 'major-seventh')
# pychord result:  []
# ---
# ['C', 'E', 'G#', 'B', 'Db', 'Ab'] 48 [4, 8, 11, 13]
# our result:  ['C-augmented-major-seventh-b9', 'E-major-sixth-on-C', 'Db-minor-seventh-on-C']
# mingus result:  []
# music21 commonName result:  center-cluster pentamirror
# music21 chordSymb  result:  ('C+M7addC#', 'augmented-major-seventh')
# pychord result:  []
# ---
# ['C', 'E', 'G', 'Bb', 'D#', 'Ab'] 48 [3, 4, 7, 10, 20]
# our result:  ['C-alt', 'C-minor-seventh-major3-b13']
# mingus result:  []
# music21 commonName result:  combinatorial I (I7)
# music21 chordSymb  result:  ('A-+M9/CaddE-', 'augmented-major-ninth')
# pychord result:  []
# ---
# ['C', 'Eb', 'Gb', 'Bb', 'D', 'F'] 48 [3, 6, 10, 14, 17]
# our result:  ['C-half-diminished-11th', 'C-minor-11th-b5', 'Gb-augmented-major-13th-#11-on-C', 'Eb-minor-13th-major-seventh-on-C']
# mingus result:  ['BbM|Cdim', 'BbM|Cm7b5', 'GbM7+|Cdim', 'GbM7+|Cm7b5']
# music21 commonName result:  melodic-minor hexachord
# music21 chordSymb  result:  ('Cø9addF', 'half-diminished-ninth')
# pychord result:  []
# ---
# ['C', 'Eb', 'Gb', 'Bb', 'D'] 48 [3, 6, 10, 14]
# our result:  ['C-half-diminished-ninth', 'C-minor-ninth-b5', 'Eb-minor-major-seventh-on-C', 'Eb-minor-sixth-major-seventh-on-C', 'Eb-minor-13th-major-seventh-on-C']
# mingus result:  ['Gbaug|Cdim', 'Gbaug|Cm7b5', 'Ebm/M7|Cdim', 'Ebm/M7|Cm7b5']
# music21 commonName result:  diminished-augmented ninth chord
# music21 chordSymb  result:  ('Cø9', 'half-diminished-ninth')
# pychord result:  []
# ---
# ['C', 'Eb', 'Gb', 'D'] 48 [3, 6, 14]
# our result:  ['C-diminished-9', 'Eb-minor-major-seventh-on-C', 'D-dominant-seventh-b9-on-C', 'Eb-minor-sixth-major-seventh-on-C', 'Eb-minor-13th-major-seventh-on-C']
# mingus result:  ['Ebm/M7|Cdim']
# music21 commonName result:  harmonic minor tetrachord
# music21 chordSymb  result:  ('CdimaddD', 'diminished')
# pychord result:  []
# ---
# ['C', 'F', 'Gb', 'A'] 48 [5, 6, 9]
# our result:  ['Gb-diminished-major-seventh-on-C']
# mingus result:  []
# music21 commonName result:  major-diminished tetrachord
# music21 chordSymb  result:  ('F/CaddF#', 'major')
# pychord result:  []
# ---
# ['F', 'Gb', 'A', 'C'] 53 [1, 4, 7]
# our result:  ['F-major-b2', 'Gb-diminished-on-F', 'Gb-diminished-major-seventh-on-F']
# mingus result:  []
# music21 commonName result:  major-diminished tetrachord
# music21 chordSymb  result:  ('FaddF#', 'major')
# pychord result:  []
# ---
# ['C', 'Eb', 'Gb', 'Bb'] 48 [3, 6, 10]
# our result:  ['C-half-diminished-seventh', 'Eb-minor-on-C', 'Eb-minor-sixth-on-C']
# mingus result:  ['C half diminished seventh', 'Eb minor sixth, third inversion', 'Ebm|Cdim']
# music21 commonName result:  half-diminished seventh chord
# music21 chordSymb  result:  ('Cø7', 'half-diminished-seventh')
# pychord result:  [<Chord: Cm7-5>, <Chord: Ebm6/C>]
# ---
# ['C', 'F', 'Gb', 'Bb'] 48 [5, 6, 10]
# our result:  ['C-half-diminished-11th', 'C-suspended-seventh-#11']
# mingus result:  []
# music21 commonName result:  minor-second quartal tetrachord
# music21 chordSymb  result:  ('Chord Symbol Cannot Be Identified', '')
# pychord result:  []
# ---
# ['C', 'E', 'F#', 'B'] 48 [4, 6, 11]
# our result:  ['C-major-seventh-b5', 'Gb-half-diminished-11th-on-C']
# mingus result:  []
# music21 commonName result:  minor-second quartal tetrachord
# music21 chordSymb  result:  ('Chord Symbol Cannot Be Identified', '')
# pychord result:  []
# ---
# ['C', 'F', 'G', 'Bb', 'Db'] 48 [5, 7, 10, 13]
# our result:  ['C-suspended-seventh-b9', 'Db-major-13th-#11-on-C', 'G-half-diminished-11th-on-C']
# mingus result:  ['Gdim|Csus4', 'Gdim|Csus47']
# music21 commonName result:  Kumoi pentachord
# music21 chordSymb  result:  ('Gø7/C', 'half-diminished-seventh')
# pychord result:  []
# ---
# ['F', 'Eb', 'A', 'C#', 'F#', 'Bb'] 53 [4, 10, 13, 17, 20]
# our result:  ['F-dominant-11th-b9-b13', 'Eb-minor-#11-on-F']
# mingus result:  []
# music21 commonName result:  combinatorial I (I11)
# music21 chordSymb  result:  ('F7+addA#,F#', 'augmented-seventh')
# pychord result:  []
# ---
# ['C', 'G', 'B', 'D'] 48 [7, 11, 14]
# our result:  ['C-suspended-second-major7', 'C-major-ninth', 'C-suspended-major-seventh', 'G-major-on-C', 'D-suspended-13th-on-C']
# mingus result:  ['GM|CM7']
# music21 commonName result:  perfect-fourth major tetrachord
# music21 chordSymb  result:  ('G/C', 'major')
# pychord result:  [<Chord: Gadd11/C>]
# ---
# ['C', 'G', 'B', 'D', 'F'] 48 [7, 11, 14, 17]
# our result:  ['C-suspended-major-seventh', 'G-dominant-seventh-on-C', 'D-minor-13th-on-C', 'G-dominant-11th-on-C']
# mingus result:  ['Bdim|CM7', 'G7|CM7']
# music21 commonName result:  Kumoi pentachord
# music21 chordSymb  result:  ('G7/C', 'dominant-seventh')
# pychord result:  []
# ---
# ['E', 'G', 'B', 'C'] 52 [3, 7, 8]
# our result:  ['E-minor-#5', 'C-major-seventh-on-E']
# mingus result:  ['C major seventh, first inversion']
# music21 commonName result:  major seventh chord
# music21 chordSymb  result:  ('Cmaj7/E', 'major-seventh')
# pychord result:  [<Chord: CM7/E>]
# ---
# ['E', 'F', 'G', 'B'] 52 [1, 3, 7]
# our result:  ['E-minor-b2', 'G-dominant-13th-on-E', 'F-diminished-major-ninth-on-E']
# mingus result:  []
# music21 commonName result:  all-interval tetrachord
# music21 chordSymb  result:  ('EmaddF', 'minor')
# pychord result:  []
# ---
# ['G', 'Bb', 'E'] 55 [3, 9]
# our result:  ['G-minor-sixth', 'E-diminished-on-G']
# mingus result:  ['G minor sixth', 'E diminished triad, first inversion']
# music21 commonName result:  diminished triad
# music21 chordSymb  result:  ('Edim/G', 'diminished')
# pychord result:  [<Chord: Edim/G>]
# ---

# %% [markdown]
# # runtime test

# %%
from datetime import datetime

# mingus
start=datetime.now()
for chord in chords_to_test:
    try:
        mingus_result = mingus.core.chords.determine(chord)
    except:
        continue
print("mingus runtime: ",datetime.now()-start)
    
    
# music21 commonName
start=datetime.now()
for chord in chords_to_test:
    chord_notes = list_pitch_name_to_num(chord, default_bias = 48, ordered = True)
    music21_chord = music21.chord.Chord(chord_notes)
    music21_commonName = music21_chord.commonName
print("music21 commonName runtime: ",datetime.now()-start)


# music21 Harmony
start=datetime.now()
for chord in chords_to_test:
    chord_notes = list_pitch_name_to_num(chord, default_bias = 48, ordered = True)
    music21_chord = music21.chord.Chord(chord_notes)
    music21_chord_symb = music21.harmony.chordSymbolFigureFromChord(music21_chord, includeChordType=True)
print("music21 harmony runtime: ",datetime.now()-start)

# mingus
start=datetime.now()
for chord in chords_to_test:
    pychord_result = pychord.find_chords_from_notes(chord)
print("pychord runtime: ",datetime.now()-start)

# ours
start=datetime.now()
for chord in chords_to_test:
    chord_notes = list_pitch_name_to_num(chord, default_bias = 48, ordered = True)
    bass, chroma24 = get_bass_chroma24(chord_notes)
    symb = bass_chroma24_to_chord_symbol(bass, chroma24, detect_inversion = True, list_all = True)
print("our runtime: ",datetime.now()-start)
# Out:
# mingus runtime:  0:00:00.011037
# music21 commonName runtime:  0:00:01.108222
# music21 harmony runtime:  0:00:01.358460
# pychord runtime:  0:00:00.005980
# our runtime:  0:00:00.075745
